# %%
import serial
import time
from math import log,ceil
from astropy.table import Table
import sys
from apscheduler.schedulers.background import BackgroundScheduler

# %%
def ReadLastGOESValue():
    t = Table.read('http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt', data_start = 30, format = 'ascii')
    lastRow = t[len(t)-1]
    return (lastRow[7])

# %%
def GOES2LEDValue( x ):
    return min(max(ceil( log(x,10)+7 ),0),4)

# %%
def InitGOES2Arduino( ):
    port = '/dev/tty.usbmodemfd131'
    return serial.Serial(port, 9600)

def Send2Arduino( ser, level ):
    ser.write( str(level).encode() )
    
def CommWithArduino( ):
    ser = InitGOES2Arduino()
    while True:
        level = GOES2LEDValue( ReadLastGOESValue() )
        Send2Arduino( ser, level )
        print( "level: ", level, "sent")
        time.sleep(60)

# %%
ser = InitGOES2Arduino()

# %%
Send2Arduino(ser,3)

# %%
CommWithArduino()
# Out:
# Downloading http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt [Done]
# level:  0 sent
# Downloading http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt [Done]
# level:  0 sent
# Downloading http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt [Done]
# level:  0 sent
# Downloading http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt [Done]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     536             try:
# --> 537                 n = os.write(self.fd, d)
#     538                 if timeout.is_non_blocking:
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-40-7aa9e9960e5a> in <module>()
# ----> 1 CommWithArduino()
#
# <ipython-input-7-ee927e8d39a6> in CommWithArduino()
#      10     while True:
#      11         level = GOES2LEDValue( ReadLastGOESValue() )
# ---> 12         Send2Arduino( ser, level )
#      13         print( "level: ", level, "sent")
#      14         time.sleep(60)
#
# <ipython-input-7-ee927e8d39a6> in Send2Arduino(ser, level)
#       4
#       5 def Send2Arduino( ser, level ):
# ----> 6     ser.write( str(level).encode() )
#       7
#       8 def CommWithArduino( ):
#
# /Applications/anaconda3/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     569                 # https://www.python.org/dev/peps/pep-0475.
#     570                 if e.errno not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
# --> 571                     raise SerialException('write failed: {}'.format(e))
#     572             except select.error as e:
#     573                 # this is for Python 2.x
#
# SerialException: write failed: [Errno 6] Device not configured

# %%
sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7a9e41e8e8ce> in <module>()
# ----> 1 sleep(3)
#
# NameError: name 'sleep' is not defined

# %%
CommWithArduino( ser )
# Out:
# Downloading http://services.swpc.noaa.gov/text/goes-xray-flux-primary.txt [Done]

# %%
    scheduler = BackgroundScheduler()

# %%
scheduler.shutdown()
ser.close()

# %%
ser.close()
# Out:
# Error submitting job "CommWithArduino (trigger: interval[0:01:00], next run at: 2018-01-06 11:08:49 CET)" to executor "default"
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.6/site-packages/apscheduler/schedulers/base.py", line 958, in _process_jobs
#     executor.submit_job(job, run_times)
#   File "/Applications/anaconda3/lib/python3.6/site-packages/apscheduler/executors/base.py", line 71, in submit_job
#     self._do_submit_job(job, run_times)
#   File "/Applications/anaconda3/lib/python3.6/site-packages/apscheduler/executors/pool.py", line 22, in _do_submit_job
#     f = self._pool.submit(run_job, job, job._jobstore_alias, run_times, self._logger.name)
#   File "/Applications/anaconda3/lib/python3.6/concurrent/futures/thread.py", line 117, in submit
#     raise RuntimeError('cannot schedule new futures after shutdown')
# RuntimeError: cannot schedule new futures after shutdown

# %% [raw]
# scheduler.start()

# %%
ser.write( b'0')
# Out:
# 1

# %%
level.to_bytes(1,'big')
# Out:
# b'\x00'
